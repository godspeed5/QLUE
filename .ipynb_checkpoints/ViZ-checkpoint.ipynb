# %%
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
import numpy as np
from scipy.stats import *
from sklearn.datasets import *

# %%
df_true = pd.read_csv('datasets/aniso_1000_20.00_25.00_2.00.csv')
df_true = df_true[df_true.layer==0]
df_true
# Out:
#      index       x       y  layer  weight   rho      delta   nh  isSeed  \
# 0        0  -51.86  -64.09      0       1  16.0    1.12272  297       0
# 1        1  171.87 -154.07      0       1  23.5    2.59943  495       0
# 2        2 -108.29   15.32      0       1  25.0    4.69145   10       0
# 3        3  175.75 -161.11      0       1  21.5    1.18228  251       0
# 4        4 -111.26  129.91      0       1  14.5    4.88806  144       0
# ..     ...     ...     ...    ...     ...   ...        ...  ...     ...
# 995    995   84.03 -154.88      0       1   1.0  999.00000   -1       0
# 996    996  203.62   87.55      0       1   1.5  999.00000   -1       0
# 997    997  108.69  -23.25      0       1   5.0    3.33714  127       0
# 998    998  185.02  141.46      0       1   2.0  999.00000   -1       0
# 999    999 -212.27  -34.71      0       1   1.5  999.00000   -1       0
#
#      clusterId
# 0            5
# 1            1
# 2            0
# 3            1
# 4            4
# ..         ...
# 995         -1
# 996         -1
# 997          3
# 998         -1
# 999         -1
#
# [1000 rows x 10 columns]

# %%
df_true.columns
# Out:
# Index(['index', 'x', 'y', 'layer', 'weight', 'rho', 'delta', 'nh', 'isSeed',
#        'clusterId'],
#       dtype='object')

# %%
isSeed = df_true.apply(lambda x: x['isSeed']>0 and x['nh']>=0, axis=1) 

# sn.scatterplot(df_true.x, df_true.y, isSeed)

# %%
sn.scatterplot(df_true.x, df_true.y, df_true.clusterId, palette='deep', legend=False)
# Out:
# /home/dhruv/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
df_seed = df_true[df_true.isSeed>0]
sn.scatterplot(df_seed.x, df_seed.y)
# Out:
# /home/dhruv/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# 6 seeds, cluster looks accurate

# %%
df_fast = pd.read_csv('D1_correct_generated_c_1.csv')
df_fast.head()
# Out:
#    Unnamed: 0           x          y  layer     weight  clusterId  \
# 0           0  149.840428 -99.655668    0.0  31.829895        3.0
# 1           1  149.708188 -98.566709    0.0  31.784517        3.0
# 2           2 -100.106417   1.329776    0.0  31.769601        1.0
# 3           3  -99.936434  -1.441901    0.0  31.750080        1.0
# 4           4  148.208547 -96.539511    0.0  31.729600        3.0
#
#            rho    NH  ClusterNumbers  isOutlier  isSeed       delta
# 0   962.058369   6.0             3.0        0.0     0.0    4.100092
# 1   958.653756   0.0             3.0        0.0     0.0    1.096959
# 2  1183.184137   inf             1.0        0.0     1.0  999.000000
# 3  1163.183600  12.0             1.0        0.0     0.0    2.207122
# 4   949.407335   6.0             3.0        0.0     0.0    0.653073

# %%
ax = sn.scatterplot(df_fast.x, df_fast.y, df_fast.ClusterNumbers)
plt.savefig('here.jpg')
# Out:
# /home/dhruv/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df = pd.read_csv('datasets/gen_data_2.csv')
df.head()
# Out:
#    Unnamed: 0          x          y  clusterId     weight  layer
# 0           0 -48.680301 -79.588956        1.0   4.773328    0.0
# 1           1 -57.669973 -20.752990        1.0   0.741019    0.0
# 2           2 -97.288593  20.932810        1.0  13.238274    0.0
# 3           3 -71.346889 -68.241059        1.0   7.022824    0.0
# 4           4 -91.504244 -23.241372        1.0  25.809310    0.0

# %%
sn.scatterplot(df.x, df.y, df.clusterId, palette="deep", legend=False)
# Out:
# /home/dhruv/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
homogeneity_completeness_v_measure(df_fast['clusterId'], df_fast['ClusterNumbers'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-52abd561d959> in <module>
# ----> 1 homogeneity_completeness_v_measure(df_fast['clusterId'], df_fast['ClusterNumbers'])
#
# NameError: name 'homogeneity_completeness_v_measure' is not defined

# %%
sn.scatterplot(df_fast.x, df_fast.y, df_fast.ClusterNumbers, palette="deep", legend=False)
# Out:
# /home/dhruv/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
np.unique(df_fast.ClusterNumbers)
# Out:
# array([0., 1., 2., 3.])

# %%
sn.scatterplot(df.x, df.y, df.ClusterNumbers, palette="deep")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-43d029951f3b> in <module>
# ----> 1 sn.scatterplot(df.x, df.y, df.ClusterNumbers, palette="deep")
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ClusterNumbers'

# %%
df[df['isSeed']==1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'isSeed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-4be953986e5f> in <module>
# ----> 1 df[df['isSeed']==1]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'isSeed'

# %%
df_fast[df_fast['isSeed']==1]
# Out:
#     Unnamed: 0           x          y  layer     weight  clusterId  \
# 2            2 -100.106417   1.329776    0.0  31.769601        1.0
# 7            7  -48.186362  95.831271    0.0  31.659558        2.0
# 22          22  147.186814 -92.793524    0.0  31.247343        3.0
#
#             rho   NH  ClusterNumbers  isOutlier  isSeed  delta
# 2   1183.184137  inf             1.0        0.0     1.0  999.0
# 7   1137.246619  inf             2.0        0.0     1.0  999.0
# 22   984.371753  inf             3.0        0.0     1.0  999.0

# %%
(df['ClusterNumbers'] == df_fast['ClusterNumbers']).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ClusterNumbers'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-aedca12ae866> in <module>
# ----> 1 (df['ClusterNumbers'] == df_fast['ClusterNumbers']).count()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'ClusterNumbers'

# %%
df_seeds = pd.read_csv('datasets/dataset1_toy.csv')
df_seeds.head()
# Out:
#    Unnamed: 0       x       y  layer  weight   rho      NH  ClusterNumbers  \
# 0           0 -125.62  -19.29    0.0     1.0  26.0  3337.0             9.0
# 1           1  -14.75 -181.03    0.0     1.0  11.0    10.0            18.0
# 2           2  -17.62 -182.86    0.0     1.0  10.0     7.0            18.0
# 3           3  -14.09 -182.71    0.0     1.0  12.0  4110.0            18.0
# 4           4  -19.80 -184.55    0.0     1.0   9.5     2.0            18.0
#
#    isOutlier  isSeed      delta
# 0        0.0     0.0   1.618178
# 1        0.0     0.0   0.554437
# 2        0.0     0.0   1.618054
# 3        0.0     0.0  13.156002
# 4        0.0     0.0   2.758351

# %%
df_no_outliers = df_fast[df_fast['isOutlier']==0]
sn.scatterplot(df_no_outliers.x, df_no_outliers.y, df_no_outliers.ClusterNumbers, palette='deep')
# Out:
# /home/dhruv/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
df_only_cluster = df_fast[df_fast['ClusterNumbers']!=0]
sn.scatterplot(df_only_cluster.x, df_only_cluster.y, df_only_cluster.ClusterNumbers, palette='deep')
# Out:
# /home/dhruv/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
sn.scatterplot(df.x, df.y, df.ClusterNumbers)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-5005f675ded3> in <module>
# ----> 1 sn.scatterplot(df.x, df.y, df.ClusterNumbers)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ClusterNumbers'

# %%
df_no_outliers = df[df['isOutlier']==0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'isOutlier'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-1c552ed25f96> in <module>
# ----> 1 df_no_outliers = df[df['isOutlier']==0]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'isOutlier'

# %%
sn.scatterplot(df_no_outliers.x, df_no_outliers.y, df_no_outliers.ClusterNumbers)
# Out:
# /home/dhruv/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
df_outliers = df[df['ClusterNumbers']==0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ClusterNumbers'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-cd4d9e49bf24> in <module>
# ----> 1 df_outliers = df[df['ClusterNumbers']==0]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'ClusterNumbers'

# %%
sn.scatterplot(df_outliers.x, df_outliers.y, df_outliers.ClusterNumbers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-5f42805d765d> in <module>
# ----> 1 sn.scatterplot(df_outliers.x, df_outliers.y, df_outliers.ClusterNumbers)
#
# NameError: name 'df_outliers' is not defined

# %%
df_outliers = df[df['isOutlier']==1]
sn.scatterplot(df_outliers.x, df_outliers.y, df_outliers.ClusterNumbers)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'isOutlier'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-2b2efa835931> in <module>
# ----> 1 df_outliers = df[df['isOutlier']==1]
#       2 sn.scatterplot(df_outliers.x, df_outliers.y, df_outliers.ClusterNumbers)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'isOutlier'

# %%
df_clusters = df[df['ClusterNumbers']!=0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ClusterNumbers'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-f40ab0e63b25> in <module>
# ----> 1 df_clusters = df[df['ClusterNumbers']!=0]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'ClusterNumbers'

# %%
sn.scatterplot(df_clusters.x, df_clusters.y, df_clusters.ClusterNumbers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-ad00607109a2> in <module>
# ----> 1 sn.scatterplot(df_clusters.x, df_clusters.y, df_clusters.ClusterNumbers)
#
# NameError: name 'df_clusters' is not defined

# %%
df['ClusterNumbers'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ClusterNumbers'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-cce870e4b800> in <module>
# ----> 1 df['ClusterNumbers'].value_counts()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'ClusterNumbers'

# %%
df['isOutlier'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'isOutlier'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-599c41936ee4> in <module>
# ----> 1 df['isOutlier'].value_counts()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'isOutlier'

# %%
df[df_true['isSeed']==1]
# Out:
# <ipython-input-50-ffdcdb31a8de>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df_true['isSeed']==1]
#      Unnamed: 0           x           y  clusterId     weight  layer
# 315          15 -102.921789  191.038300        2.0   3.463342    0.0
# 517         217  -13.335949   54.456482        2.0  10.909704    0.0
# 617          17  165.943877 -134.626346        3.0  22.439471    0.0
# 619          19  166.835955 -138.674355        3.0  20.005323    0.0
# 644          44  163.508532 -141.843865        3.0  14.374254    0.0
# 875         275  181.293893 -137.069778        3.0  13.978274    0.0

# %%
sn.scatterplot(df[df['ClusterNumbers'].isin([10,6,1,8])].x, df[df['ClusterNumbers'].isin([10,6,1,8])].y, df[df['ClusterNumbers'].isin([10,6,1,8])].ClusterNumbers, palette='deep')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ClusterNumbers'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-84d275c224b4> in <module>
# ----> 1 sn.scatterplot(df[df['ClusterNumbers'].isin([10,6,1,8])].x, df[df['ClusterNumbers'].isin([10,6,1,8])].y, df[df['ClusterNumbers'].isin([10,6,1,8])].ClusterNumbers, palette='deep')
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'ClusterNumbers'

# %%
df['ClusterNumbers'] == [4,8]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ClusterNumbers'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-bdc14b737014> in <module>
# ----> 1 df['ClusterNumbers'] == [4,8]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'ClusterNumbers'

# %%
df_true = pd.read_csv('datasets/toyDetector_5k_20_25_2.csv')
df_true = df_true[df_true.layer==0]
df_true
# Out:
#       index       x       y  layer  weight   rho      delta    nh  isSeed  \
# 0         0 -125.62  -19.29      0       1  26.0   0.662118  3953       0
# 1         1 -125.55  -15.88      0       1  27.5  16.566900  3940       0
# 2         2 -124.31  -19.01      0       1  25.5   0.381187  3957       0
# 3         3 -129.71  -20.03      0       1  26.5   1.647790     5       0
# 4         4 -125.19  -17.73      0       1  26.5   1.231790  3958       0
# ...     ...     ...     ...    ...     ...   ...        ...   ...     ...
# 4995   4995  219.80  -98.78      0       1  17.5  31.438100  2485       0
# 4996   4996  -91.30 -203.86      0       1   1.5   7.883360  4964       0
# 4997   4997  211.69   26.87      0       1  20.0  13.403800  4782       0
# 4998   4998  120.60 -175.63      0       1   9.0  12.042100  3233       0
# 4999   4999  -23.16 -116.06      0       1  12.0   6.120290  3513       0
#
#       clusterId
# 0           206
# 1           206
# 2           206
# 3           206
# 4           206
# ...         ...
# 4995         44
# 4996        846
# 4997        392
# 4998        361
# 4999        591
#
# [5000 rows x 10 columns]

# %%
sn.scatterplot(df_true.x, df_true.y, df_true.clusterId)
# Out:
# /home/dhruv/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
df = pd.read_csv('datasets/dataset1.csv')
df.head()
# Out:
#    Unnamed: 0      x      y  layer  weight   rho     NH  ClusterNumbers  \
# 0           0 -51.86 -64.09    0.0     1.0  16.0  147.0             0.0
# 1           1  98.02 -43.68    0.0     1.0  16.5  572.0             0.0
# 2           2 -66.32 -35.50    0.0     1.0  27.5  205.0             0.0
# 3           3 -52.16 -34.61    0.0     1.0  18.5  199.0             0.0
# 4           4 -82.97 -17.03    0.0     1.0  25.5  541.0             0.0
#
#    isOutlier  isSeed     delta
# 0        0.0     0.0  7.229115
# 1        0.0     0.0  1.888280
# 2        0.0     0.0  3.497571
# 3        0.0     0.0  0.404969
# 4        0.0     0.0  2.760072

# %%
df[df['isSeed']==1]
# Out:
#      Unnamed: 0       x       y  layer  weight   rho     NH  ClusterNumbers  \
# 51           51  -84.64  113.85    0.0     1.0  32.5    inf             1.0
# 168         168  -54.23   79.47    0.0     1.0  32.0    inf             2.0
# 175         175  164.00 -135.47    0.0     1.0  28.0  778.0             3.0
# 205         205  -69.63  -36.63    0.0     1.0  29.5  800.0             4.0
# 212         212  -55.87   76.23    0.0     1.0  32.0    inf             5.0
# 214         214  135.46  -95.24    0.0     1.0  32.5    inf             6.0
# 375         375  -70.27  -28.62    0.0     1.0  29.5  800.0             7.0
# 608         608  167.18 -144.11    0.0     1.0  28.0    inf             8.0
# 694         694  169.16 -143.03    0.0     1.0  28.0    inf             9.0
# 972         972 -102.79    4.48    0.0     1.0  32.0    inf            10.0
#
#      isOutlier  isSeed       delta
# 51         0.0     1.0  999.000000
# 168        0.0     1.0  999.000000
# 175        0.0     1.0   35.449417
# 205        0.0     1.0   38.039891
# 212        0.0     1.0  999.000000
# 214        0.0     1.0  999.000000
# 375        0.0     1.0   32.008327
# 608        0.0     1.0  999.000000
# 694        0.0     1.0  999.000000
# 972        0.0     1.0  999.000000

# %%
df[df['NH']==101]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, x, y, layer, weight, rho, NH, ClusterNumbers, isOutlier, isSeed, delta]
# Index: []

# %%
chosen_layer = 0
sortpar = 'weight'
df = df[df['layer']==chosen_layer].sort_values(sortpar, ascending=False, ignore_index=True)

# %%
semiMajorAxis =50
phi = 2*np.pi/3
semiMinorAxis = 10
varX1 = semiMajorAxis**2 * np.cos(phi)**2 + semiMinorAxis**2 * np.sin(phi)**2
varX2 = semiMajorAxis** 2 * np.sin(phi)**2 + semiMinorAxis**2 * np.cos(phi)**2
# cov12 = (semiMajorAxis**2 - semiMinorAxis**2) * np.sin(phi) * np.cos(phi) 
cov12 = (2*np.random.random() -1)*np.sqrt(varX1*varX2)
cova = np.array([[varX1, cov12], [cov12, varX2]])
cova
# Out:
# array([[ 700.        , -944.79892055],
#        [-944.79892055, 1900.        ]])

# %%
n_samples = [300]*2
n_noise = 5

means = [[-100,0],[100,0]]
covs = [800*np.eye(2)]*2
prefactor = [1e5]*3
n_clusters = len(means)
df = pd.DataFrame(columns=['x','y','clusterId'])
for i in range(n_clusters):
    a = np.random.multivariate_normal(mean=means[i], cov=covs[i], size=n_samples[i])
    df1 = pd.DataFrame(columns=['x','y','clusterId'], data=np.c_[a,(i+1)*np.ones((n_samples[i]))])
    df1['weight'] = prefactor[i]*multivariate_normal.pdf(df1[['x', 'y']].values, mean=means[i], cov=covs[i])
    df = pd.concat([df,df1])
noise = np.random.uniform(-250,250, (n_noise,2))
n = pd.DataFrame(columns=['x','y','clusterId', 'weight'], data=np.c_[noise,0*np.ones((n_noise)), 2*np.random.random(n_noise)])
df = pd.concat([df,n])
df['layer']=np.zeros(len(df))

# %%
sn.scatterplot(data=df, x='x',y='y', hue='clusterId')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
df['weight']
# Out:
# 0    12.038493
# 1    16.142954
# 2    16.343505
# 3     7.646503
# 4     4.972934
#        ...
# 0     1.421199
# 1     1.844686
# 2     0.716901
# 3     1.246664
# 4     1.994759
# Name: weight, Length: 605, dtype: float64

# %%
df.to_csv('datasets/gen_data.csv')

# %%
#     plt.savefig('homogeneities_varied_energy.png')

# %%
cova = np.array([[ 700.        ,  -96.88368962],
                [ -96.88368962, 1900.        ]])
np.linalg.eig(cova)
# Out:
# (array([ 692.22829178, 1907.77170822]),
#  array([[-0.99679807,  0.07996004],
#         [-0.07996004, -0.99679807]]))

# %%
guess = []
n_noises = [50,100,150,200,250,300,350,400,450,500]
for i in n_noises:
    k = chi2.ppf(1-(1/i),df=2)
    l = np.sqrt(692*1907)*k*np.pi/(500**2)
#     binom.pmf(i)
    guess.append(l)
guess
# Out:
# [0.11294568755312565,
#  0.13295783594162555,
#  0.1446641923077652,
#  0.1529699843301255,
#  0.15941245713543847,
#  0.1646763406962656,
#  0.16912689083252777,
#  0.17298213271862606,
#  0.17638269706240492,
#  0.17942460552393844]

# %%
np.log(300+n_noise)
# Out:
# [50, 100, 150, 200, 250, 300, 350, 400, 450, 500]

# %%
chi2.ppf(0.99,df=2)
# Out:
# 9.21034037197618

# %%
a = np.load('output/homogeneities_varied_energy.npy')
n=6
noise_sizes = list(range(n))

prefactors = [1,1.1,1.2,1.3,1.4,1.5,1.5,1.7,1.8,1.9,2,10,100,500]
a = a[:n,:,:]
print(a.shape)
for i in range(a.shape[2]):
    c_scores = a[:,:,i]
    plt.plot(noise_sizes, np.mean(c_scores, axis=1), label=str(prefactors[i]))
    plt.fill_between(noise_sizes, np.mean(c_scores,axis=1)-np.std(c_scores, axis=1), np.mean(c_scores, axis=1)+np.std(c_scores, axis=1), alpha=0.2)
# 
plt.legend()
#TODO: fix units, distance in terms of sigma, stop at 5, factors: [1, 10, 100]
# Out:
# (6, 2, 14)

# %%
chi2.ppf(.999999,2)
# Out:
# 27.631021115871036

# %%
plt.plot(range(1,11), guess)

# %%
# Generate the moons dataset
X, y = make_moons(n_samples=1000, noise = 0.03)
X = 100*X
# Create a scatterplot using seaborn
# plt.figure(figsize=(8, 6))
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y, palette="Set1", s=70, alpha=0.7)
plt.title("Moons Dataset Scatterplot")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend(["Class 0", "Class 1"])
# plt.grid(True)
plt.show()
data = pd.DataFrame({'x': X[:, 0], 'y': X[:, 1], 'clusterId': y, 'layer': np.zeros(len(X)), 'weight': 2*np.ones(len(X))})
data.to_csv('datasets/moons.csv')

# %%
data.head()
# Out:
#             x           y  clusterId  layer  weight
# 0  245.205786   30.703306          0    0.0     1.0
# 1  223.714105   87.973922          0    0.0     1.0
# 2  274.853548 -116.713400          1    0.0     1.0
# 3  254.568836   22.793941          0    0.0     1.0
# 4 -232.366487   90.958818          0    0.0     1.0

# %%
X, y = make_circles(n_samples=1000, noise=0.02, factor =0.5)
X = 200*X
# Create a scatterplot using seaborn
# plt.figure(figsize=(8, 6))
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y, palette="Set1", s=70, alpha=0.7)
plt.title("Circles Dataset Scatterplot")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend(["Class 0", "Class 1"])
data = pd.DataFrame({'x': X[:, 0], 'y': X[:, 1], 'clusterId': y, 'layer': np.zeros(len(X)), 'weight': 2.5*np.ones(len(X))})
data.to_csv('datasets/circles.csv')

# %%
data.head()
# Out:
#             x           y  clusterId  layer  weight
# 0 -163.969585 -115.774948          1    0.0     1.0
# 1  200.819786   -1.389693          1    0.0     1.0
# 2  203.680107   31.070538          1    0.0     1.0
# 3 -245.022804  -13.353399          0    0.0     1.0
# 4 -141.038100  137.347883          1    0.0     1.0
